# %%
# %pip install openai langchain_openai langchain
# Out:
# Collecting openai
#   Obtaining dependency information for openai from https://files.pythonhosted.org/packages/13/2d/1cb19289feef689206cd8995d7be6b5d76b7e8d64fd51438acecc11ee395/openai-1.108.2-py3-none-any.whl.metadata
#   Downloading openai-1.108.2-py3-none-any.whl.metadata (29 kB)
# Collecting langchain_openai
#   Obtaining dependency information for langchain_openai from https://files.pythonhosted.org/packages/67/31/af0486b7ad8a49f3c5c852ca2b3a7f6d8526cc71a405045dd959c36ec5db/langchain_openai-0.3.33-py3-none-any.whl.metadata
#   Downloading langchain_openai-0.3.33-py3-none-any.whl.metadata (2.4 kB)
# Collecting langchain
#   Obtaining dependency information for langchain from https://files.pythonhosted.org/packages/f6/d5/4861816a95b2f6993f1360cfb605aacb015506ee2090433a71de9cca8477/langchain-0.3.27-py3-none-any.whl.metadata
#   Downloading langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\kase\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.10.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Obtaining dependency information for distro<2,>=1.7.0 from https://files.pythonhosted.org/packages/12/b3/231ffd4ab1fc9d679809f356cebee130ac7daa00d6d6f3206dd4fd137e9e/distro-1.9.0-py3-none-any.whl.metadata
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Obtaining dependency information for httpx<1,>=0.23.0 from https://files.pythonhosted.org/packages/2a/39/e50c7c3a983047577ee07d2a9e53faf5a69493943ec3f6a384bdc792deb2/httpx-0.28.1-py3-none-any.whl.metadata
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Obtaining dependency information for jiter<1,>=0.4.0 from https://files.pythonhosted.org/packages/ed/42/5823ec2b1469395a160b4bf5f14326b4a098f3b6898fbd327366789fa5d3/jiter-0.11.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading jiter-0.11.0-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\kase\appdata\local\programs\python\python312\lib\site-packages (from openai) (2.11.9)
# Requirement already satisfied: sniffio in c:\users\kase\appdata\local\programs\python\python312\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\kase\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\kase\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.15.0)
# Collecting langchain-core<1.0.0,>=0.3.76 (from langchain_openai)
#   Obtaining dependency information for langchain-core<1.0.0,>=0.3.76 from https://files.pythonhosted.org/packages/77/b5/501c0ffcb09c734457ceaa86bc7b1dd37b6a261147bd653add03b838aacb/langchain_core-0.3.76-py3-none-any.whl.metadata
#   Downloading langchain_core-0.3.76-py3-none-any.whl.metadata (3.7 kB)
# Collecting tiktoken<1,>=0.7 (from langchain_openai)
#   Obtaining dependency information for tiktoken<1,>=0.7 from https://files.pythonhosted.org/packages/f5/6e/5b71578799b72e5bdcef206a214c3ce860d999d579a3b56e74a6c8989ee2/tiktoken-0.11.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading tiktoken-0.11.0-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9 (from langchain)
#   Obtaining dependency information for langchain-text-splitters<1.0.0,>=0.3.9 from https://files.pythonhosted.org/packages/58/0d/41a51b40d24ff0384ec4f7ab8dd3dcea8353c05c973836b5e289f1465d4f/langchain_text_splitters-0.3.11-py3-none-any.whl.metadata
#   Downloading langchain_text_splitters-0.3.11-py3-none-any.whl.metadata (1.8 kB)
# Collecting langsmith>=0.1.17 (from langchain)
#   Obtaining dependency information for langsmith>=0.1.17 from https://files.pythonhosted.org/packages/ae/d1/b2b2ea7b443c6b028aca209d2e653256912906900cc146e64c65201211b7/langsmith-0.4.30-py3-none-any.whl.metadata
#   Downloading langsmith-0.4.30-py3-none-any.whl.metadata (14 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Obtaining dependency information for SQLAlchemy<3,>=1.4 from https://files.pythonhosted.org/packages/bc/09/405c915a974814b90aa591280623adc6ad6b322f61fd5cff80aeaef216c9/sqlalchemy-2.0.43-cp312-cp312-win_amd64.whl.metadata
#   Downloading sqlalchemy-2.0.43-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: requests<3,>=2 in c:\users\kase\appdata\local\programs\python\python312\lib\site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\kase\appdata\local\programs\python\python312\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: idna>=2.8 in c:\users\kase\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\users\kase\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.8.3)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Obtaining dependency information for httpcore==1.* from https://files.pythonhosted.org/packages/7e/f5/f66802a942d491edb555dd61e3a9961140fd64c90bce1eafd741609d334d/httpcore-1.0.9-py3-none-any.whl.metadata
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: h11>=0.16 in c:\users\kase\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<1.0.0,>=0.3.76->langchain_openai)
#   Obtaining dependency information for tenacity!=8.4.0,<10.0.0,>=8.1.0 from https://files.pythonhosted.org/packages/e5/30/643397144bfbfec6f6ef821f36f33e57d35946c44a2352d3c9f0ae847619/tenacity-9.1.2-py3-none-any.whl.metadata
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<1.0.0,>=0.3.76->langchain_openai)
#   Obtaining dependency information for jsonpatch<2.0,>=1.33 from https://files.pythonhosted.org/packages/73/07/02e16ed01e04a374e644b575638ec7987ae846d25ad97bcc9945a3ee4b0e/jsonpatch-1.33-py2.py3-none-any.whl.metadata
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging>=23.2 in c:\users\kase\appdata\roaming\python\python312\site-packages (from langchain-core<1.0.0,>=0.3.76->langchain_openai) (23.2)
# Collecting orjson>=3.9.14 (from langsmith>=0.1.17->langchain)
#   Obtaining dependency information for orjson>=3.9.14 from https://files.pythonhosted.org/packages/35/b8/9e3127d65de7fff243f7f3e53f59a531bf6bb295ebe5db024c2503cc0726/orjson-3.11.3-cp312-cp312-win_amd64.whl.metadata
#   Downloading orjson-3.11.3-cp312-cp312-win_amd64.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/43.0 kB ? eta -:--:--
#      ---------------------------------------- 43.0/43.0 kB ? eta 0:00:00
# Collecting requests-toolbelt>=1.0.0 (from langsmith>=0.1.17->langchain)
#   Obtaining dependency information for requests-toolbelt>=1.0.0 from https://files.pythonhosted.org/packages/3f/51/d4db610ef29373b879047326cbf6fa98b6c1969d6f6dc423279de2b1be2c/requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith>=0.1.17->langchain)
#   Obtaining dependency information for zstandard>=0.23.0 from https://files.pythonhosted.org/packages/79/3b/fa54d9015f945330510cb5d0b0501e8253c127cca7ebe8ba46a965df18c5/zstandard-0.25.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kase\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\kase\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\kase\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kase\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kase\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (2.5.0)
# Collecting greenlet>=1 (from SQLAlchemy<3,>=1.4->langchain)
#   Obtaining dependency information for greenlet>=1 from https://files.pythonhosted.org/packages/e9/08/b0814846b79399e585f974bbeebf5580fbe59e258ea7be64d9dfb253c84f/greenlet-3.2.4-cp312-cp312-win_amd64.whl.metadata
#   Downloading greenlet-3.2.4-cp312-cp312-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\kase\appdata\local\programs\python\python312\lib\site-packages (from tiktoken<1,>=0.7->langchain_openai) (2025.7.34)
# Requirement already satisfied: colorama in c:\users\kase\appdata\roaming\python\python312\site-packages (from tqdm>4->openai) (0.4.6)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.76->langchain_openai)
#   Obtaining dependency information for jsonpointer>=1.9 from https://files.pythonhosted.org/packages/71/92/5e77f98553e9e75130c78900d000368476aed74276eb8ae8796f65f00918/jsonpointer-3.0.0-py2.py3-none-any.whl.metadata
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Downloading openai-1.108.2-py3-none-any.whl (948 kB)
#    ---------------------------------------- 0.0/948.4 kB ? eta -:--:--
#    ---------------- ---------------------- 409.6/948.4 kB 12.5 MB/s eta 0:00:01
#    ---------------------------------- ---- 829.4/948.4 kB 13.0 MB/s eta 0:00:01
#    --------------------------------------- 948.4/948.4 kB 11.9 MB/s eta 0:00:00
# Downloading langchain_openai-0.3.33-py3-none-any.whl (74 kB)
#    ---------------------------------------- 0.0/75.0 kB ? eta -:--:--
#    ---------------------------------------- 75.0/75.0 kB 4.0 MB/s eta 0:00:00
# Downloading langchain-0.3.27-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------- ----------------------- 0.4/1.0 MB 12.8 MB/s eta 0:00:01
#    -------------------------------- ------- 0.8/1.0 MB 13.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 10.7 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ---------------------------------------- 0.0/73.5 kB ? eta -:--:--
#    ---------------------------------------- 73.5/73.5 kB 4.0 MB/s eta 0:00:00
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.8 kB ? eta -:--:--
#    ---------------------------------------- 78.8/78.8 kB 4.3 MB/s eta 0:00:00
# Downloading jiter-0.11.0-cp312-cp312-win_amd64.whl (203 kB)
#    ---------------------------------------- 0.0/203.5 kB ? eta -:--:--
#    --------------------------------------- 203.5/203.5 kB 12.1 MB/s eta 0:00:00
# Downloading langchain_core-0.3.76-py3-none-any.whl (447 kB)
#    ---------------------------------------- 0.0/447.5 kB ? eta -:--:--
#    ------------------------------------ -- 419.8/447.5 kB 13.2 MB/s eta 0:00:01
#    ---------------------------------------- 447.5/447.5 kB 9.5 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.3.11-py3-none-any.whl (33 kB)
# Downloading langsmith-0.4.30-py3-none-any.whl (386 kB)
#    ---------------------------------------- 0.0/386.3 kB ? eta -:--:--
#    --------------------------------------  378.9/386.3 kB 23.0 MB/s eta 0:00:01
#    --------------------------------------- 386.3/386.3 kB 11.8 MB/s eta 0:00:00
# Downloading sqlalchemy-2.0.43-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ------- -------------------------------- 0.4/2.1 MB 13.2 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.1 MB 13.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.2/2.1 MB 13.2 MB/s eta 0:00:01
#    ------------------------------- -------- 1.7/2.1 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 12.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 11.3 MB/s eta 0:00:00
# Downloading tiktoken-0.11.0-cp312-cp312-win_amd64.whl (884 kB)
#    ---------------------------------------- 0.0/884.3 kB ? eta -:--:--
#    ------------------ -------------------- 419.8/884.3 kB 12.8 MB/s eta 0:00:01
#    ------------------------------------ -- 829.4/884.3 kB 13.0 MB/s eta 0:00:01
#    --------------------------------------- 884.3/884.3 kB 11.2 MB/s eta 0:00:00
# Downloading greenlet-3.2.4-cp312-cp312-win_amd64.whl (299 kB)
#    ---------------------------------------- 0.0/299.9 kB ? eta -:--:--
#    ---------------------------------------- 299.9/299.9 kB 9.3 MB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading orjson-3.11.3-cp312-cp312-win_amd64.whl (131 kB)
#    ---------------------------------------- 0.0/131.4 kB ? eta -:--:--
#    ---------------------------------------- 131.4/131.4 kB 7.6 MB/s eta 0:00:00
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ---------------------------------------- 0.0/54.5 kB ? eta -:--:--
#    ---------------------------------------- 54.5/54.5 kB 2.8 MB/s eta 0:00:00
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl (506 kB)
#    ---------------------------------------- 0.0/506.3 kB ? eta -:--:--
#    -------------------------------- ------ 419.8/506.3 kB 12.8 MB/s eta 0:00:01
#    --------------------------------------- 506.3/506.3 kB 10.6 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Installing collected packages: zstandard, tenacity, orjson, jsonpointer, jiter, httpcore, greenlet, distro, tiktoken, SQLAlchemy, requests-toolbelt, jsonpatch, httpx, openai, langsmith, langchain-core, langchain-text-splitters, langchain_openai, langchain
# Successfully installed SQLAlchemy-2.0.43 distro-1.9.0 greenlet-3.2.4 httpcore-1.0.9 httpx-0.28.1 jiter-0.11.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.27 langchain-core-0.3.76 langchain-text-splitters-0.3.11 langchain_openai-0.3.33 langsmith-0.4.30 openai-1.108.2 orjson-3.11.3 requests-toolbelt-1.0.0 tenacity-9.1.2 tiktoken-0.11.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_openai import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.memory import ConversationBufferWindowMemory
from langchain.chains import LLMChain

# %%
# 상담 챗봇 초기화 함수
def get_chatbot_chain():
    # LLM
    llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.7)

    # 템플릿
    template = """당신은 따뜻하고 공감적인 상담사 역활을 하는 챗봇입니다.
    사용자의 고민을 차분하고 친절하게 들어주고, 조언을 제공합니다.
    조언의 길이는 길지않게 최대 40자 내의 답변을 하며,
    상대방이 더 많은 대화를 할 수 있도록 이끌어 내야합니다.. 
    """
    # 프롬프트
    prompt = ChatPromptTemplate.from_messages([
        ("system", template), ("ai", "{chat_history}"), ("human", "{message}")
    ])

    # 대화 내용을 기억하는 메모리
    memory = ConversationBufferWindowMemory(k=2,
        memory_key="chat_history", 
        return_messages=True
    )

    # LLM 체인
    chain = LLMChain(
        llm=llm,
        prompt=prompt,
        memory=memory
    )

    return chain

# %%
get_chatbot_chain().run(message='오늘 하루 힘들었어요')
# Out:
# C:\Users\kase\AppData\Local\Temp\ipykernel_4656\2406806362.py:24: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain = LLMChain(
# C:\Users\kase\AppData\Local\Temp\ipykernel_4656\2397801398.py:1: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   get_chatbot_chain().run(message='오늘 하루 힘들었어요')
# '힘든 하루를 보내셨군요. 무슨 일이 있었나요?'
